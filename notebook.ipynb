# %%
print ("Welcome to RECOMB Papers")
# Out:
# Welcome to RECOMB Papers.

# %% [raw]
# import React, { useState } from 'react';
#
# const CustomComponent: React.FC<{}> = ({}) => {
# 	return (
# 		<div>
# 			<h1>Hello, World!</h1>
# 		</div>
# 	);
# };

# %%
UI.addWidget(CustomComponent())
